# %%
from IPython.display import Image
from IPython.display import HTML
Image(url="https://www.easycard.com.tw/_upload/images/2005061134030.jpg")
# Out:
# <img src="https://www.easycard.com.tw/_upload/images/2005061134030.jpg"/>
